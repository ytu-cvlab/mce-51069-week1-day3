# %% [markdown]
# ## Questions
#
#  1. Numpy
#  2. Numpy
#  3. Matplotlib
#  4. cv2 (solved)
#  5. Hard one (plt + cv2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2

# %%
# No.1 mean square error
target = np.array([1, 2, 1, 2])
predict = np.array([2, 1, 2, 4])

def mean_square_error(target, predict):
    return 

mean_square_error()

# %%
with open("color.pkl", 'r') as reader:
    r = 
    g = 
    b = 

# No.2 
def stacking_exercise(red, green, blue):
    '''
    Stack the three channel Images.
    Inputs:
        red(ndarray) -> 100, 120
        green(ndarray) -> 120, 100
        blue(ndarray) -> 100, 120
    Output
        rgb_image(ndarray) -> 100, 120, 3
    '''

    return rgb_image


plt.imshow(stacking_exercise(red, green, blue))
plt.show()

# %%
# %matplotlib inline
# No. 3 matplotlib (sawtooth)
x = np.linspace(-10, 10, 100)

def sigmoid(x, figsize=(10, 8)):
    '''
    Plot the sawtooth wave
    Inputs:
        x(float) -> input data points
    Output
        fig() -> 
    '''
    ###CODE HERE###
    y = 1/(1+np.exp(-x))
    plt.figure(figsize=(figsize))
    fig =plt.plot(x, y)
    ###############
    return fig
    
fig = sigmoid(x)
plt.show()

# %%
# No. 4 cv2
def read_img(file_name):
    '''
    Return 
        img_array(ndarray) --> RGB image array.
    '''
    
    return img_array


def get_green_channel(img):
    '''
    Return
        green(ndarray) --> shape = (h, w)
    '''
    return green


def resize_img(img, h, w):
    return resized


def rotate_img(img, degree, scale=1):
    h, w = img.shape
    M = cv2.getRotationMatrix2D((w//2, h//2), angle=degree, scale=scale)
    rotated = cv2.warpAffine(img, M, (w, h))
    return rotated

# %%
img = read_img('images/cvml.png')
green = get_green_channel(img)
resized = resize_img(green, 500, 500)
rotated = rotate_img(resized, 45)

# %%
plt.imshow(rotated, cmap='gray')
plt.show()

# %%
# hard-one(cv2)
logo_half1 = mpimg.imread('images/cvml.png')
logo_half2 = mpimg.imread('images/cvml.png')

def stack_images(half1, half2):
    '''
    Return
        logo(ndarray) ->
    
    '''
    logo = np.hstack((half1, half2))
    return logo

plt.imshow(stack_images(logo_half1, logo_half2))
plt.show()

# %%
# !python test/testA1.py
# Out:
# Importing Jupyter notebook from Assignment1.ipynb
# test_get_green_channel (__main__.TestNotebook) ... ok
# test_read_img (__main__.TestNotebook) ... ok
# test_resize_img (__main__.TestNotebook) ... ok
# test_rotated_img (__main__.TestNotebook) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.334s
#
# OK

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
